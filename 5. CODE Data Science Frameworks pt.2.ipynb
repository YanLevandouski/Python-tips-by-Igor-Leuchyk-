# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
df = pd.read_excel (r'C:\Users\Igor_Leuchyk\Desktop\Useful_materials\Personal\RD_DS\DFs\data2.xls')
df
# Out:
#       sepal_length sepal_width petal_length  petal_width          species      \
# 0             5.93        3.66         4.94         2.69  Iris-versicolor NaN
# 1             6.89        3.79         6.16         2.81   Iris-virginica NaN
# 2             6.70        3.64         5.99         2.81   Iris-virginica NaN
# 3             6.74        2.68         4.71         2.29  Iris-versicolor NaN
# 4             5.96        4.16         2.99         1.56      Iris-setosa NaN
# ...            ...         ...          ...          ...              ...  ..
# 2419          6.96        3.76         2.73         0.65      Iris-setosa NaN
# 2420          7.43        4.14         6.11         3.00   Iris-virginica NaN
# 2421          6.54        4.56         1.69         0.87      Iris-setosa NaN
# 2422          7.11        4.66          5.3         3.80   Iris-virginica NaN
# 2423          6.75        3.58         6.02         2.77   Iris-virginica NaN
#
#              .
# 0      NaN NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2424 entries, 0 to 2423
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  2394 non-null   float64
#  1   sepal_width   2393 non-null   object
#  2   petal_length  2393 non-null   object
#  3   petal_width   2393 non-null   float64
#  4   species       2424 non-null   object
#  5                 0 non-null      float64
#  6                 0 non-null      float64
#  7   .             0 non-null      float64
# dtypes: float64(5), object(3)
# memory usage: 151.6+ KB

# %%
#as we can see columns # 5, 6, 7 contain only NaNs. I believe that we can remove them

# %%
df1 = df.drop(df.columns[[5, 6, 7]], axis=1)

# %%
df1.describe()
# Out:
#        sepal_length  petal_width
# count   2394.000000  2393.000000
# mean       6.469511     2.215061
# std        2.540472     1.755113
# min      -10.000000     0.000000
# 25%        5.930000     1.450000
# 50%        6.700000     2.220000
# 75%        7.490000     2.940000
# max       70.000000    70.000000

# %%
print(df1.dtypes)
# Out:
# sepal_length    float64
# sepal_width      object
# petal_length     object
# petal_width     float64
# species          object
# dtype: object

# %%
df1[['sepal_width', 'petal_length']] = df1[['sepal_width', 'petal_length']].astype(str)

# %%
np.unique(df1['sepal_width'])
# Out:
# array(['0', '10', '2', '2.03', '2.2', '2.24', '2.25',
#        '2.2800000000000002', '2.3', '2.35', '2.3600000000000003', '2.38',
#        '2.4', '2.4499999999999997', '2.46', '2.4699999999999998',
#        '2.4800000000000004', '2.5', '2.52', '2.53', '2.54', '2.56',
#        '2.58', '2.59', '2.5900000000000003', '2.5999999999999996', '2.6',
#        '2.6199999999999997', '2.67', '2.6799999999999997', '2.68',
#        '2.6899999999999995', '2.6900000000000004', '2.7', '2.72', '2.73',
#        '2.7300000000000004', '2.74', '2.75', '2.76', '2.7600000000000002',
#        '2.77', '2.79', '2.8', '2.8099999999999996', '2.81', '2.82',
#        '2.83', '2.84', '2.8400000000000003', '2.8499999999999996', '2.85',
#        '2.86', '2.8600000000000003', '2.87', '2.88', '2.9',
#        '2.9099999999999997', '2.91', '2.92', '2.9299999999999997', '2.93',
#        '2.94', '2.9499999999999997', '2.96', '2.9699999999999998', '2.98',
# ...

# %%
np.unique(df1['petal_length'])
# Out:
# array(['0', '1', '1.1', '1.16', '1.2', '1.21', '1.24', '1.25', '1.3',
#        '1.32', '1.33', '1.3599999999999999', '1.3900000000000001', '1.4',
#        '1.4000000000000001', '1.41', '1.43', '1.45', '1.46', '1.47',
#        '1.48', '1.49', '1.5', '1.51', '1.52', '1.5299999999999998',
#        '1.53', '1.55', '1.56', '1.57', '1.5899999999999999', '1.59',
#        '1.6', '1.6099999999999999', '1.61', '1.62', '1.6300000000000001',
#        '1.64', '1.6400000000000001', '1.65', '1.66', '1.67', '1.68',
#        '1.6800000000000002', '1.69', '1.7', '1.71', '1.7299999999999998',
#        '1.73', '1.74', '1.75', '1.76', '1.77', '1.78', '1.79',
#        '1.7999999999999998', '1.8', '1.8099999999999998', '1.81',
#        '1.8199999999999998', '1.82', '1.84', '1.8499999999999999', '1.85',
#        '1.8699999999999999', '1.87', '1.88', '1.8800000000000001', '1.89',
#        '1.8900000000000001', '1.9', '1.9000000000000001', '1.91',
# ...

# %%
# I've detected "nan", "Random" and "random" values in these 2 columns. That's why I couldn't describe them before

# %%
df1['sepal_width'] = df1['sepal_width'].str.replace('Random', '')

# %%
df1['sepal_width'] = df1['sepal_width'].str.replace('random', '')

# %%
df1['sepal_width'] = df1['sepal_width'].str.replace('nan', '')

# %%
df1['sepal_width'] = pd.to_numeric(df1['sepal_width'])

# %%
df1['petal_length'] = df1['petal_length'].str.replace('random', '')

# %%
df1['petal_length'] = df1['petal_length'].str.replace('nan', '')

# %%
df1['petal_length'] = pd.to_numeric(df1['petal_length'])

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count   2394.000000  2391.000000   2392.000000  2393.000000
# mean       6.469511     3.978156      4.626731     2.215061
# std        2.540472     1.716950      2.412232     1.755113
# min      -10.000000     0.000000      0.000000     0.000000
# 25%        5.930000     3.445000      2.740000     1.450000
# 50%        6.700000     4.000000      5.090000     2.220000
# 75%        7.490000     4.580000      6.150000     2.940000
# max       70.000000    70.000000     70.000000    70.000000

# %%
print(df1.dtypes)
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# I've made the 'sepal_width', 'petal_length' floats (at last)

# %%
df1.isna().any()
# Out:
# sepal_length     True
# sepal_width      True
# petal_length     True
# petal_width      True
# species         False
# dtype: bool

# %%
# only column "species" contain no NAs
df1.describe(include = 'all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width          species
# count    2394.000000  2391.000000   2392.000000  2393.000000             2424
# unique           NaN          NaN           NaN          NaN                4
# top              NaN          NaN           NaN          NaN  Iris-versicolor
# freq             NaN          NaN           NaN          NaN              800
# mean        6.469511     3.978156      4.626731     2.215061              NaN
# std         2.540472     1.716950      2.412232     1.755113              NaN
# min       -10.000000     0.000000      0.000000     0.000000              NaN
# 25%         5.930000     3.445000      2.740000     1.450000              NaN
# 50%         6.700000     4.000000      5.090000     2.220000              NaN
# 75%         7.490000     4.580000      6.150000     2.940000              NaN
# max        70.000000    70.000000     70.000000    70.000000              NaN

# %%
exact_NAs = df1[df1.isna().any(axis = 1)]

# %%
print(exact_NAs)
# Out:
#       sepal_length  sepal_width  petal_length  petal_width          species
# 95             NaN          NaN           NaN          NaN   Iris-virginica
# 259            NaN          NaN           NaN          NaN   Iris-virginica
# 282            NaN          NaN           NaN          NaN   Iris-virginica
# 283            NaN          NaN           NaN          NaN      Iris-setosa
# 288           5.83         4.86          3.46          NaN      Iris-setosa
# 299            NaN          NaN           NaN          NaN   Iris-virginica
# 365            NaN          NaN           NaN          NaN   Iris-virginica
# 388            NaN          NaN           NaN          NaN      Iris-setosa
# 468            NaN          NaN           NaN          NaN  Iris-versicolor
# 521            NaN          NaN           NaN          NaN   Iris-virginica
# 721            NaN          NaN           NaN          NaN      Iris-setosa
# ...

# %%
# no we can face with exact list of NAs

# %%
df2 = df1.fillna(df1.mean(numeric_only = True), limit = 12, axis = 0)

# %%
df2
# Out:
#       sepal_length  sepal_width  petal_length  petal_width          species
# 0             5.93         3.66          4.94         2.69  Iris-versicolor
# 1             6.89         3.79          6.16         2.81   Iris-virginica
# 2             6.70         3.64          5.99         2.81   Iris-virginica
# 3             6.74         2.68          4.71         2.29  Iris-versicolor
# 4             5.96         4.16          2.99         1.56      Iris-setosa
# ...            ...          ...           ...          ...              ...
# 2419          6.96         3.76          2.73         0.65      Iris-setosa
# 2420          7.43         4.14          6.11         3.00   Iris-virginica
# 2421          6.54         4.56          1.69         0.87      Iris-setosa
# 2422          7.11         4.66          5.30         3.80   Iris-virginica
# 2423          6.75         3.58          6.02         2.77   Iris-virginica
#
# [2424 rows x 5 columns]

# %%
exact_NAs2 = df2[df2.isna().any(axis = 1)]

# %%
print(exact_NAs2)
# Out:
#       sepal_length  sepal_width  petal_length  petal_width          species
# 1064      6.469511     3.978156      4.626731          NaN      Iris-setosa
# 1078      7.200000          NaN      7.100000         3.94   Iris-virginica
# 1106           NaN          NaN           NaN          NaN      Iris-setosa
# 1170      8.020000          NaN      6.590000         2.24   Iris-virginica
# 1244           NaN          NaN           NaN          NaN      Iris-setosa
# 1414           NaN          NaN           NaN          NaN  Iris-versicolor
# 1538      8.370000          NaN           NaN         4.21   Iris-virginica
# 1583           NaN          NaN           NaN          NaN  Iris-versicolor
# 1663           NaN          NaN           NaN          NaN   Iris-virginica
# 1736           NaN          NaN           NaN          NaN   Iris-virginica
# 1870           NaN          NaN           NaN          NaN   Iris-virginica
# ...

# %%
#unfortunately, I don't know how to replace NAs by slices, so I counted them by myself :(

# %%
df3 = df2.ffill(axis = 0, limit = 1)

# %%
df3
# Out:
#       sepal_length  sepal_width  petal_length  petal_width          species
# 0             5.93         3.66          4.94         2.69  Iris-versicolor
# 1             6.89         3.79          6.16         2.81   Iris-virginica
# 2             6.70         3.64          5.99         2.81   Iris-virginica
# 3             6.74         2.68          4.71         2.29  Iris-versicolor
# 4             5.96         4.16          2.99         1.56      Iris-setosa
# ...            ...          ...           ...          ...              ...
# 2419          6.96         3.76          2.73         0.65      Iris-setosa
# 2420          7.43         4.14          6.11         3.00   Iris-virginica
# 2421          6.54         4.56          1.69         0.87      Iris-setosa
# 2422          7.11         4.66          5.30         3.80   Iris-virginica
# 2423          6.75         3.58          6.02         2.77   Iris-virginica
#
# [2424 rows x 5 columns]

# %%
exact_NAs3 = df3[df3.isna().any(axis = 1)]

# %%
print(exact_NAs3)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
df3.isna().any()
# Out:
# sepal_length    False
# sepal_width     False
# petal_length    False
# petal_width     False
# species         False
# dtype: bool

# %%
# I don't understand how to limit ffill and bfill :(((((

# %%
df3.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count   2424.000000  2424.000000   2424.000000  2424.000000
# mean       6.472646     3.975647      4.627872     2.215929
# std        2.526542     1.706344      2.403922     1.745716
# min      -10.000000     0.000000      0.000000     0.000000
# 25%        5.940000     3.447500      2.767500     1.457500
# 50%        6.690000     3.990000      5.070000     2.220000
# 75%        7.490000     4.570000      6.150000     2.940000
# max       70.000000    70.000000     70.000000    70.000000

# %%
# after these manipulations I can assume that "count" for all the columns has increased from 2391-2394 to 2424,
# also Standard Deviation ("std") has changed: ('sepal_length' - decreased, 'sepal_width' - decreased, 'petal_length' - increased, 'petal_width' - decreased)
# And min for "sepal_length" is also below zero (as in the 1st DB). I guess that it is an error in the default DB

# %%
import seaborn as sb

# %%
sb.pairplot(df3, hue = 'species')

# %%
# according to graphics above, petal_width has linear dependence on petal_length (but it hardly can be visible)

# %%
X = df3.drop(labels = ['petal_width', 'species'], axis = 1)
Y = df3['petal_width']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split (X, Y, test_size = 0.4, random_state = 101)

# %%
X_train
# Out:
#       sepal_length  sepal_width  petal_length
# 1032          5.84         4.56          2.99
# 1678          7.94         5.84          3.57
# 1067          6.99         5.05          5.47
# 1469          8.06         4.71          6.14
# 1481          7.61         5.65          3.17
# ...            ...          ...           ...
# 599           7.63         3.65          5.93
# 1599          7.18         3.88          5.91
# 1361          7.95         4.19          5.01
# 1547          7.27         3.78          5.96
# 863           6.31         3.81          2.62
#
# [1454 rows x 3 columns]

# %%
X_test
# Out:
#       sepal_length  sepal_width  petal_length
# 1522          5.30         2.60          3.64
# 814           6.97         4.74          3.51
# 1800          6.24         4.22          3.08
# 1971          6.37         4.21          5.20
# 209           5.25         3.60          3.56
# ...            ...          ...           ...
# 68            6.50         3.00          5.80
# 182           6.64         2.68          5.52
# 1079          6.52         3.29          4.62
# 850           8.07         3.67          6.81
# 70            6.30         4.30          2.25
#
# [970 rows x 3 columns]

# %%
Y_train
# Out:
# 1032    1.40
# 1678    1.93
# 1067    3.23
# 1469    3.44
# 1481    2.07
#         ...
# 599     2.86
# 1599    2.45
# 1361    2.27
# 1547    2.85
# 863     1.41
# Name: petal_width, Length: 1454, dtype: float64

# %%
Y_test
# Out:
# 1522    1.54
# 814     3.58
# 1800    1.60
# 1971    2.28
# 209     1.88
#         ...
# 68      2.20
# 182     2.49
# 1079    2.26
# 850     2.02
# 70      1.83
# Name: petal_width, Length: 970, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
linear_regr = LinearRegression()

# %%
linear_regr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
linear_regr.predict(X_test)
pred = linear_regr.predict(X_test)

# %%
pred
# Out:
# array([ 1.52677873,  1.92722679,  1.64470076,  2.49409533,  1.70667513,
#         0.95729594,  2.76544673,  3.05726043,  2.8911001 ,  2.67223562,
#         2.78692134,  2.45711058,  2.13019783,  1.74187175,  2.59437546,
#         2.65568926,  1.52874382,  2.40390416,  2.51722078,  2.28923839,
#         2.0514607 ,  3.02492466,  2.97850293,  3.73818581,  2.77743402,
#         1.19097135,  3.08419385,  1.76505533,  1.9200519 ,  1.46469935,
#         3.21305972,  1.40704667,  1.29626988,  1.75613848,  1.12984833,
#         1.12637183,  2.26622927,  2.3035067 ,  2.18901882, -0.48337422,
#         0.71202549,  1.27642301,  2.20686413,  0.83488639,  3.66713771,
#         2.82191093,  3.52973067,  2.52309564,  1.83726975,  1.33645197,
#         2.03747738,  2.64024101,  3.03007762,  1.66692784,  2.29893283,
#         3.5002346 ,  1.28295998,  1.5922954 ,  3.6505361 ,  1.97702425,
#         3.16668959,  1.71123165,  1.7847644 ,  1.45423341,  2.01581657,
# ...

# %%
#As I can assume, my linear regression works +/- correctly (not with 100% accuracy but works)
#As I can see: the bigger the petal_length - the bigger petal_width
